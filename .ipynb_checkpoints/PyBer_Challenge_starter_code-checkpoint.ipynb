# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df
# Out:
#                     city              date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24  30.24  2343912425577
# 2     Port Samanthamouth   2019-02-24 4:29  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22  23.44  5149245426178
# 4             South Jack   2019-03-06 4:28  34.58  3908451377344
# ...                  ...               ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04  13.38  8550365057598
# 2371     Lake Latoyabury   2019-01-30 0:05  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# 4               46  Urban
# ...            ...    ...
# 2370             6  Rural
# 2371             2  Rural
# 2372             1  Rural
# 2373             4  Rural
# 2374             1  Rural
#
# [2375 rows x 6 columns]

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type

rides_by_city = pyber_data_df["ride_id"].groupby(pyber_data_df["type"]).count()
rides_by_city = rides_by_city.rename('Total Rides')
rides_by_city
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: Total Rides, dtype: int64

# %%
# 2. Get the total drivers for each city type

drivers_by_city = city_data_df["driver_count"].groupby(city_data_df["type"]).sum()
drivers_by_city = drivers_by_city.rename('Total Drivers')
drivers_by_city
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: Total Drivers, dtype: int64

# %%
#  3. Get the total amount of fares for each city type

fares_by_city = pyber_data_df["fare"].groupby(pyber_data_df["type"]).sum()
fares_by_city = fares_by_city.rename('Total Fares')
fares_by_city
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: Total Fares, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 

average_fare_by_city_type = pyber_data_df.groupby(pyber_data_df["type"]).mean()["fare"]
average_fare_by_city_type = average_fare_by_city_type.rename('Average Fare per Ride')
average_fare_by_city_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: Average Fare per Ride, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 

average_fare_per_driver_by_city_type = fares_by_city / drivers_by_city
average_fare_per_driver_by_city_type = average_fare_per_driver_by_city_type.rename('Average Fare per Driver')
average_fare_per_driver_by_city_type
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# Name: Average Fare per Driver, dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pd.options.display.float_format = '${:,.2f}'.format
pyber_summary_df = pd.concat([rides_by_city, drivers_by_city, fares_by_city, average_fare_by_city_type, average_fare_per_driver_by_city_type], axis=1)    


pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78    $4,327.93                 $34.62
# Suburban          625            490   $19,356.33                 $30.97
# Urban            1625           2405   $39,854.38                 $24.53
#
#           Average Fare per Driver
# type
# Rural                      $55.49
# Suburban                   $39.50
# Urban                      $16.57

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.

#pd.options.display.float_format = '${:,.2f}'.format

#pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("{:.2f}".format)
#pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["	Average Fare per Ride"].map("${:.2f}".format)
#pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:.2f}".format)
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78    $4,327.93                 $34.62
# Suburban          625            490   $19,356.33                 $30.97
# Urban            1625           2405   $39,854.38                 $24.53
#
#           Average Fare per Driver
# Rural                      $55.49
# Suburban                   $39.50
# Urban                      $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city              date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14 $13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24 $30.24  2343912425577
# 2     Port Samanthamouth   2019-02-24 4:29 $33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22 $23.44  5149245426178
# 4             South Jack   2019-03-06 4:28 $34.58  3908451377344
# ...                  ...               ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04 $13.38  8550365057598
# 2371     Lake Latoyabury   2019-01-30 0:05 $20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03 $11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22 $44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20 $55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# 4               46  Urban
# ...            ...    ...
# 2370             6  Rural
# 2371             2  Rural
# 2372             1  Rural
# 2373             4  Rural
# 2374             1  Rural
#
# [2375 rows x 6 columns]

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

fare_by_date_df = pyber_data_df.groupby(['date', 'type'])[['fare']].mean()
fare_by_date_df
# Out:
#                             fare
# date             type
# 2019-01-01 0:08  Urban    $37.91
# 2019-01-01 0:46  Suburban $47.74
# 2019-01-01 12:32 Suburban $25.56
# 2019-01-01 14:40 Urban     $5.42
# 2019-01-01 14:42 Urban    $12.31
# ...                          ...
# 2019-05-08 1:54  Urban    $32.69
# 2019-05-08 2:31  Urban    $41.33
# 2019-05-08 4:20  Urban    $21.99
# 2019-05-08 4:39  Urban    $18.45
# 2019-05-08 7:29  Urban    $18.55
#
# [2364 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
fare_by_date_df = fare_by_date_df.reset_index()
fare_by_date_df
# Out:
#                   date      type   fare
# 0      2019-01-01 0:08     Urban $37.91
# 1      2019-01-01 0:46  Suburban $47.74
# 2     2019-01-01 12:32  Suburban $25.56
# 3     2019-01-01 14:40     Urban  $5.42
# 4     2019-01-01 14:42     Urban $12.31
# ...                ...       ...    ...
# 2359   2019-05-08 1:54     Urban $32.69
# 2360   2019-05-08 2:31     Urban $41.33
# 2361   2019-05-08 4:20     Urban $21.99
# 2362   2019-05-08 4:39     Urban $18.45
# 2363   2019-05-08 7:29     Urban $18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 

fare_pivot_table = fare_by_date_df.pivot_table(['fare'], index=['date'], columns='type')
#fare_pivot_table = fare_by_date_df.pivot_table(['fare'], index=['date'], columns='type')
fare_pivot_table
# Out:
#                   fare
# type             Rural Suburban  Urban
# date
# 2019-01-01 0:08    NaN      NaN $37.91
# 2019-01-01 0:46    NaN   $47.74    NaN
# 2019-01-01 12:32   NaN   $25.56    NaN
# 2019-01-01 14:40   NaN      NaN  $5.42
# 2019-01-01 14:42   NaN      NaN $12.31
# ...                ...      ...    ...
# 2019-05-08 1:54    NaN      NaN $32.69
# 2019-05-08 2:31    NaN      NaN $41.33
# 2019-05-08 4:20    NaN      NaN $21.99
# 2019-05-08 4:39    NaN      NaN $18.45
# 2019-05-08 7:29    NaN      NaN $18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
date_range_df = fare_pivot_table.loc['2019-01-01':'2019-04-29']
date_range_df
# Out:
#                   fare
# type             Rural Suburban  Urban
# date
# 2019-01-01 0:08    NaN      NaN $37.91
# 2019-01-01 0:46    NaN   $47.74    NaN
# 2019-01-01 12:32   NaN   $25.56    NaN
# 2019-01-01 14:40   NaN      NaN  $5.42
# 2019-01-01 14:42   NaN      NaN $12.31
# ...                ...      ...    ...
# 2019-04-28 4:34    NaN      NaN $40.46
# 2019-04-28 8:15    NaN      NaN $22.86
# 2019-04-28 9:03    NaN      NaN $15.00
# 2019-04-28 9:10    NaN      NaN  $5.73
# 2019-04-28 9:25    NaN      NaN $37.35
#
# [2182 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
date_range_df.index = pd.to_datetime(date_range_df.index)
date_range_df
# Out:
#                      fare
# type                Rural Suburban  Urban
# date
# 2019-01-01 00:08:00   NaN      NaN $37.91
# 2019-01-01 00:46:00   NaN   $47.74    NaN
# 2019-01-01 12:32:00   NaN   $25.56    NaN
# 2019-01-01 14:40:00   NaN      NaN  $5.42
# 2019-01-01 14:42:00   NaN      NaN $12.31
# ...                   ...      ...    ...
# 2019-04-28 04:34:00   NaN      NaN $40.46
# 2019-04-28 08:15:00   NaN      NaN $22.86
# 2019-04-28 09:03:00   NaN      NaN $15.00
# 2019-04-28 09:10:00   NaN      NaN  $5.73
# 2019-04-28 09:25:00   NaN      NaN $37.35
#
# [2182 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
date_range_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2182 entries, 2019-01-01 00:08:00 to 2019-04-28 09:25:00
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (fare, Rural)     114 non-null    float64
#  1   (fare, Suburban)  570 non-null    float64
#  2   (fare, Urban)     1501 non-null   float64
# dtypes: float64(3)
# memory usage: 68.2 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
weekly_fare_df = date_range_df.resample('W-Sun').sum()

weekly_fare_df
# Out:
#               fare
# type         Rural  Suburban     Urban
# date
# 2019-01-06 $187.92   $721.60 $1,661.68
# 2019-01-13  $67.65 $1,070.82 $2,050.43
# 2019-01-20 $306.00 $1,218.20 $1,939.02
# 2019-01-27 $179.69 $1,203.28 $2,098.47
# 2019-02-03 $333.08 $1,042.79 $2,070.49
# 2019-02-10 $115.80   $974.34 $2,162.64
# 2019-02-17  $95.82 $1,045.50 $2,235.07
# 2019-02-24 $419.06 $1,412.74 $2,466.29
# 2019-03-03 $175.14   $858.46 $2,218.20
# 2019-03-10 $303.94   $925.27 $2,470.93
# 2019-03-17 $163.39   $906.20 $2,044.42
# 2019-03-24 $189.76 $1,122.20 $2,368.37
# 2019-03-31 $199.42 $1,017.77 $1,942.77
# 2019-04-07 $501.24 $1,010.73 $2,291.78
# 2019-04-14 $269.79   $784.82 $2,364.30
# 2019-04-21 $214.14 $1,123.44 $2,285.28
# 2019-04-28 $191.85 $1,357.75 $2,190.44

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

weekly_fare_df['x1'] = weekly_fare_df.index
weekly_fare_df.plot(kind='line', x='x1', y=[0, 1, 2])




plt.ylabel("Fare ($USD)")
plt.xlabel("")
plt.title("Total Fare by City Type")
plt.legend(["Rural", "Suburban", "Urban"], title="type", loc="center")

plt.show()
